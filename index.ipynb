# %% [markdown]
# # Reading API Documentation
#
# ## Introduction
# We've now covered an example API request, but how on Earth would you know how to do that on your own? The answer is through documentation! All APIs will have associated documentation, and while there are substantial similarities, all will be different to one degree or another. The best way to get more comfortable is to practice! So with that, let's take a look at the yelp documentation associated with our previous example.
#
# ## Objectives
#
# You will be able to:
#
# * Interpret API documentation into Python code
# * Make requests using OAuth
#
# Start by navigating to https://www.yelp.com/developers/documentation/v3/get_started and having a look for yourself!
#
# <img src="images/yelp_overview.png" width="800">
#
# As you see at the top, the first piece of almost every API is authentication.
#
# This is where we started in the previous codealong, where we went to https://www.yelp.com/developers/v3/manage_app and created a new app.
#
# <img src="images/yelp_app.png"  width="800">

# %% [markdown]
# Let's take a closer look at Yelp's authentication documentation:
# https://www.yelp.com/developers/documentation/v3/authentication
#
# <img src="images/yelp_auth.png" width="800">

# %% [markdown]
# Notice in the documentation, it gives us the specific format "Put the API Key in the request header as "Authorization: Bearer <YOUR API KEY>"." This is what we passed in our get request.
#
#
# Before we do this, let's import your authentication token which you have appropriately stored in **a separate file** from the codealong before.

# %%
'''import json

#Our previous function for loading our api key file
def get_keys(path):
    with open(path) as f:
        return json.load(f)'''
from config import yelp_api_key

# %% [markdown]
# > **Note**: Like before, change the file path below to be your root directory.
# If you're not sure what your username is, check it with `pwd`
# For example, my current working directory is ```/Users/matthew.mitchell/Documents/dsc-using-yelp-api-codealong```
# So the line below would become:
# ```keys = get_keys("/Users/matthew.mitchell/.secret/yelp_api.json")```

# %%
'''keys = get_keys("/Users/YOUR_USERNAME_HERE/.secret/yelp_api.json")

api_key = keys['api_key']

#While you may wish to print out these api keys to check that they imported properly,
#be sure to clear the output before uploading to Github. 
#Again, you don't want your keys stolen!!!'''
# Out:
# 'keys = get_keys("/Users/YOUR_USERNAME_HERE/.secret/yelp_api.json")\n\napi_key = keys[\'api_key\']\n\n#While you may wish to print out these api keys to check that they imported properly,\n#be sure to clear the output before uploading to Github. \n#Again, you don\'t want your keys stolen!!!'

# %%
import requests

# %%
url = #This will be our next step
header = {"Authorization" : "Bearer {}".format(yelp_api_key)}
response = requests.get(url, header=header)
# Out:
#   File "<ipython-input-4-8834bfd32c37>", line 1
#     url = #This will be our next step
#                                      ^
# SyntaxError: invalid syntax

# %% [markdown]
#  With that, let's take a look at how the rest of our request should be formatted. Go to https://www.yelp.com/developers/documentation/v3/business_search  and take a couple of minutes to look things over.
#
#  <img src="images/yelp_docs.png"  width="800">

# %% [markdown]
# Notice the first part is the format of the get request! This is the URL we pass into our get request. From there, the available parameters that you can pass are listed. These define your query, some are required while others are optional.
#
# Reviewing our python package we thus have:

# %%
url = 'https://api.yelp.com/v3/businesses/search'

headers = {
        'Authorization': 'Bearer {}'.format(yelp_api_key),
    }

url_params = {
                'location': 'NYC'
            }
response = requests.get(url, headers=headers, params=url_params)

# %%
response.json()
# Out:
# {'businesses': [{'id': 'H4jJ7XB3CetIr1pg56CczQ',
#    'alias': 'levain-bakery-new-york',
#    'name': 'Levain Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zgjSt_RGjXQMJxYxYSo-bQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/levain-bakery-new-york?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 8216,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7773520936702,
#     'longitude': -73.980282552649},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1484 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1484 3rd Ave', 'New York, NY 10023']},
#    'phone': '+19174643769',
#    'display_phone': '(917) 464-3769',
#    'distance': 8082.367282240455},
#   {'id': 'V7lXZKBDzScDeGB8JmnzSA',
#    'alias': 'katzs-delicatessen-new-york',
#    'name': "Katz's Delicatessen",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/B6xNx79cSE7bFxqERBYOhg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/katzs-delicatessen-new-york?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 12397,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.722237, 'longitude': -73.9875259},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '205 E Houston St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['205 E Houston St', 'New York, NY 10002']},
#    'phone': '+12122542246',
#    'display_phone': '(212) 254-2246',
#    'distance': 1952.3706239726876},
#   {'id': '44SY464xDHbvOcjDzRbKkQ',
#    'alias': 'ippudo-ny-new-york-7',
#    'name': 'Ippudo NY',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zF3EgqHCk7zBUwD2B3WTEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ippudo-ny-new-york-7?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 9984,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73092, 'longitude': -73.99015},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '65 4th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['65 4th Ave', 'New York, NY 10003']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2854.3012674083675},
#   {'id': 'xEnNFXtMLDF5kZDxfaCJgA',
#    'alias': 'the-halal-guys-new-york-2',
#    'name': 'The Halal Guys',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/24lb-VP2zVySsY9cq45ETw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-halal-guys-new-york-2?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 9502,
#    'categories': [{'alias': 'foodstands', 'title': 'Food Stands'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'halal', 'title': 'Halal'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76477, 'longitude': -73.98614},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': 'W 53rd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['W 53rd St', 'New York, NY 10019']},
#    'phone': '+13475271505',
#    'display_phone': '(347) 527-1505',
#    'distance': 6579.837043273955},
#   {'id': 'jVncyqXwlx_D9f2xZn05tg',
#    'alias': 'the-metropolitan-museum-of-art-new-york-3',
#    'name': 'The Metropolitan Museum of Art',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oqhwmydKw-jPcUhoxBGGyg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-metropolitan-museum-of-art-new-york-3?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 2898,
#    'categories': [{'alias': 'artmuseums', 'title': 'Art Museums'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.779449, 'longitude': -73.963245},
#    'transactions': [],
#    'location': {'address1': '1000 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1000 5th Ave', 'New York, NY 10028']},
#    'phone': '+12125357710',
#    'display_phone': '(212) 535-7710',
#    'distance': 8634.601734170283},
#   {'id': 'xOw4aafJRji9XomGunlvcQ',
#    'alias': 'central-park-new-york',
#    'name': 'Central Park',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ru79-OUEcTI2_yVQqZBTjQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/central-park-new-york?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 2484,
#    'categories': [{'alias': 'parks', 'title': 'Parks'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.782418740809,
#     'longitude': -73.9656022837641},
#    'transactions': [],
#    'location': {'address1': '14 E 60th St',
#     'address2': '',
#     'address3': 'Central Park Conservancy',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['14 E 60th St',
#      'Central Park Conservancy',
#      'New York, NY 10022']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 8893.835855571413},
#   {'id': 'WHRHK3S1mQc3PmhwsGRvbw',
#    'alias': 'bibble-and-sip-new-york-2',
#    'name': 'Bibble & Sip',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/z2QRyxNTchTqtX-VL8kL6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bibble-and-sip-new-york-2?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 4821,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76282, 'longitude': -73.98518},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '253 W 51st St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['253 W 51st St', 'New York, NY 10019']},
#    'phone': '+16466495116',
#    'display_phone': '(646) 649-5116',
#    'distance': 6427.9212521553545},
#   {'id': 'jnEv25Y2DosTq2sNnvmC9g',
#    'alias': 'los-tacos-no-1-new-york',
#    'name': 'Los Tacos No.1',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FU44TYl3PzXsE06G4W5aog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/los-tacos-no-1-new-york?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 3017,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7425547, 'longitude': -74.0060838},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '75 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['75 9th Ave', 'New York, NY 10011']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4244.358699250552},
#   {'id': 'zj8Lq1T8KIC5zwFief15jg',
#    'alias': 'prince-street-pizza-new-york-2',
#    'name': 'Prince Street Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZAukOyv530w4KjOHC5YY1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/prince-street-pizza-new-york-2?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 3665,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7229087705545,
#     'longitude': -73.9944863319397},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '27 Prince St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['27 Prince St', 'New York, NY 10012']},
#    'phone': '+12129664100',
#    'display_phone': '(212) 966-4100',
#    'distance': 1941.9638172538225},
#   {'id': 'jjJc_CrkB2HodEinB6cWww',
#    'alias': 'lovemama-new-york',
#    'name': 'LoveMama',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bLlFKTlVuLfmF-lIDGIjZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lovemama-new-york?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 5096,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'malaysian', 'title': 'Malaysian'},
#     {'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7303859, 'longitude': -73.9860613},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '174 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['174 2nd Ave', 'New York, NY 10003']},
#    'phone': '+12122545370',
#    'display_phone': '(212) 254-5370',
#    'distance': 2858.7729410008346},
#   {'id': 'j1S3NUrkB3BVT49n_e76NQ',
#    'alias': 'best-bagel-and-coffee-new-york',
#    'name': 'Best Bagel & Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9-8DVzhwfzFS5GUCq3O6NA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/best-bagel-and-coffee-new-york?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 3327,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7522683, 'longitude': -73.9910861},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '225 W 35th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['225 W 35th St', 'New York, NY 10001']},
#    'phone': '+12125644409',
#    'display_phone': '(212) 564-4409',
#    'distance': 5213.5315009761325},
#   {'id': 'UA2M9QFZghe-9th2KwLoWQ',
#    'alias': 'burger-and-lobster-new-york-4',
#    'name': 'Burger & Lobster',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/r0TGigSI5cXeM_fWBct4SA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/burger-and-lobster-new-york-4?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 5443,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74007, 'longitude': -73.99344},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '39 W 19th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['39 W 19th St', 'New York, NY 10011']},
#    'phone': '+16468337532',
#    'display_phone': '(646) 833-7532',
#    'distance': 3849.54386751767},
#   {'id': 'B3_K2kUVbYOU0VaLcj_LTw',
#    'alias': 'thai-villa-new-york-2',
#    'name': 'Thai Villa',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/oELHjgVFiisZdXpn91cd5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-villa-new-york-2?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 3430,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73902, 'longitude': -73.99065},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '5 E 19th St',
#     'address2': 'G Floor',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5 E 19th St', 'G Floor', 'New York, NY 10003']},
#    'phone': '+12128029999',
#    'display_phone': '(212) 802-9999',
#    'distance': 3744.570399827637},
#   {'id': 'veq1Bl1DW3UWMekZJUsG1Q',
#    'alias': 'gramercy-tavern-new-york',
#    'name': 'Gramercy Tavern',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MgfPMoFNmjIWcrMxTZbsvw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gramercy-tavern-new-york?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 2920,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73844, 'longitude': -73.98825},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '42 E 20th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42 E 20th St', 'New York, NY 10003']},
#    'phone': '+12124770777',
#    'display_phone': '(212) 477-0777',
#    'distance': 3702.8075801197165},
#   {'id': 'JION8hhg7q6zyayHYwhxIw',
#    'alias': 'the-high-line-new-york',
#    'name': 'The High Line',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/c8aPLzWrFFiGay3eTWEMWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-high-line-new-york?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 2345,
#    'categories': [{'alias': 'parks', 'title': 'Parks'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7396, 'longitude': -74.0084399},
#    'transactions': [],
#    'location': {'address1': '820 Washington St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['820 Washington St', 'New York, NY 10014']},
#    'phone': '+12122069922',
#    'display_phone': '(212) 206-9922',
#    'distance': 3992.412193223877},
#   {'id': '4yPqqJDJOQX69gC66YUDkA',
#    'alias': 'peter-luger-brooklyn-2',
#    'name': 'Peter Luger',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cWn0RZ0qacJB04sK0Eyafw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/peter-luger-brooklyn-2?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 5779,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.709945, 'longitude': -73.962478},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '178 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['178 Broadway', 'Brooklyn, NY 11211']},
#    'phone': '+17183877400',
#    'display_phone': '(718) 387-7400',
#    'distance': 2728.016921522817},
#   {'id': 'kViIWJFfAfWPpJOwAXBKGA',
#    'alias': 'national-september-11-memorial-museum-new-york',
#    'name': 'National September 11 Memorial Museum',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yoe6Wha7gQlTBNIeFO0UhQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/national-september-11-memorial-museum-new-york?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 1424,
#    'categories': [{'alias': 'museums', 'title': 'Museums'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71143, 'longitude': -74.012481},
#    'transactions': [],
#    'location': {'address1': '180 Greenwich St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['180 Greenwich St', 'New York, NY 10007']},
#    'phone': '+12122665211',
#    'display_phone': '(212) 266-5211',
#    'distance': 1671.270457850173},
#   {'id': 'nU4XBdvxDABXqZ6CnB8Dig',
#    'alias': 'clinton-street-baking-company-new-york-5',
#    'name': 'Clinton Street Baking Company',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DWHdizJ9bKbXN4yq6nbwAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/clinton-street-baking-company-new-york-5?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 5096,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.721128, 'longitude': -73.983933},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '4 Clinton St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4 Clinton St', 'New York, NY 10002']},
#    'phone': '+16466026263',
#    'display_phone': '(646) 602-6263',
#    'distance': 1950.282829638887},
#   {'id': 'FEVQpbOPOwAPNIgO7D3xxw',
#    'alias': 'shake-shack-new-york-2',
#    'name': 'Shake Shack',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5Tnq5PlJ1wkEU5op-yolcg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shake-shack-new-york-2?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 5595,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'foodstands', 'title': 'Food Stands'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7417320034487,
#     'longitude': -73.9881852006622},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': 'E 23rd St Madison Avenue',
#     'address2': '',
#     'address3': 'Madison Square Park',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['E 23rd St Madison Avenue',
#      'Madison Square Park',
#      'New York, NY 10010']},
#    'phone': '+12128896600',
#    'display_phone': '(212) 889-6600',
#    'distance': 4067.6399448732245},
#   {'id': 'vRrVSB-LegwUwIxpkeRVtQ',
#    'alias': 'le-bernardin-new-york',
#    'name': 'Le Bernardin',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/c54rsVNmAhn_Ccz4tIXI_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-bernardin-new-york?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 2540,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.761557, 'longitude': -73.981763},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '155 W 51st St',
#     'address2': '',
#     'address3': 'The Equitable Bldg',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['155 W 51st St',
#      'The Equitable Bldg',
#      'New York, NY 10019']},
#    'phone': '+12125541515',
#    'display_phone': '(212) 554-1515',
#    'distance': 6328.07179784047}],
#  'total': 24800,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %% [markdown]
# Note that location or latitude and longitude are the only required parameters. That said, you are free to pass as many parameters as you want such as:

# %%
url = 'https://api.yelp.com/v3/businesses/search'

headers = {
        'Authorization': 'Bearer {}'.format(yelp_api_key),
    }

url_params = {
                'location': 'NYC',
                'term' : 'pizza',
                'limit' : 50,
                'price' : "1,2,3,4",
                'open_now' : True
            }
response = requests.get(url, headers=headers, params=url_params)

# %%
response.json()
# Out:
# {'businesses': [{'id': 'zj8Lq1T8KIC5zwFief15jg',
#    'alias': 'prince-street-pizza-new-york-2',
#    'name': 'Prince Street Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZAukOyv530w4KjOHC5YY1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/prince-street-pizza-new-york-2?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 3665,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7229087705545,
#     'longitude': -73.9944863319397},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '27 Prince St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['27 Prince St', 'New York, NY 10012']},
#    'phone': '+12129664100',
#    'display_phone': '(212) 966-4100',
#    'distance': 1941.9638172538225},
#   {'id': 'WIhm0W9197f_rRtDziq5qQ',
#    'alias': 'lombardis-pizza-new-york-4',
#    'name': "Lombardi's Pizza",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UZ6V_hobp1KpYDPOHNoCKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lombardis-pizza-new-york-4?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 6114,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7215934960083,
#     'longitude': -73.9955956044561},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '32 Spring St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32 Spring St', 'New York, NY 10012']},
#    'phone': '+12129417994',
#    'display_phone': '(212) 941-7994',
#    'distance': 1798.9959778083735},
#   {'id': 'C8j0q4Ma_S5hBGuAI-aaww',
#    'alias': 'di-fara-pizza-brooklyn',
#    'name': 'Di Fara Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4dfe9qpe20P-vi3qFjWd4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/di-fara-pizza-brooklyn?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 3519,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.625093, 'longitude': -73.961531},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1424 Ave J',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11230',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1424 Ave J', 'Brooklyn, NY 11230']},
#    'phone': '+17182581367',
#    'display_phone': '(718) 258-1367',
#    'distance': 9352.269072867253},
#   {'id': 'WG639VkTjmK5dzydd1BBJA',
#    'alias': 'rubirosa-new-york-2',
#    'name': 'Rubirosa',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LuSzR8cpVQRofXOT_bMi1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rubirosa-new-york-2?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 2265,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.722766, 'longitude': -73.996233},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '235 Mulberry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['235 Mulberry St', 'New York, NY 10012']},
#    'phone': '+12129650500',
#    'display_phone': '(212) 965-0500',
#    'distance': 1932.9467701334759},
#   {'id': 'v1DHGRNCH9247WLYoaoA9A',
#    'alias': 'l-industrie-pizzeria-brooklyn',
#    'name': "L'industrie Pizzeria",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SRL_RztRRUijgQwt67daGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-industrie-pizzeria-brooklyn?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 532,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71162, 'longitude': -73.95783},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '254 S 2nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['254 S 2nd St', 'Brooklyn, NY 11211']},
#    'phone': '+17185990002',
#    'display_phone': '(718) 599-0002',
#    'distance': 3145.016041338447},
#   {'id': '2ggi1luerd3Mf_C82JvCYg',
#    'alias': 'grimaldis-pizzeria-brooklyn-4',
#    'name': "Grimaldi's Pizzeria",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KnocNRTl04953MdDXH9y7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grimaldis-pizzeria-brooklyn-4?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 4614,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.702583, 'longitude': -73.9932413},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 Front St', 'Brooklyn, NY 11201']},
#    'phone': '+17188584300',
#    'display_phone': '(718) 858-4300',
#    'distance': 330.34746206527655},
#   {'id': 'xxgcU_oFIox_pAmroo9WwA',
#    'alias': 'front-street-pizza-brooklyn',
#    'name': 'Front Street Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ybrfmg0lGdBoJRM7X1_s3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/front-street-pizza-brooklyn?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 360,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70244, 'longitude': -73.98943},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '80 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['80 Front St', 'Brooklyn, NY 11201']},
#    'phone': '+17188753700',
#    'display_phone': '(718) 875-3700',
#    'distance': 550.4392264831844},
#   {'id': 'FhXjAc6nKLf414KxYujUHw',
#    'alias': 'robertas-brooklyn-2',
#    'name': "Roberta's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8fY9fA5TtCF0ebdTNph9mQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/robertas-brooklyn-2?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 2906,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.705043534338, 'longitude': -73.93357123374},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '261 Moore St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['261 Moore St', 'Brooklyn, NY 11206']},
#    'phone': '+17184171118',
#    'display_phone': '(718) 417-1118',
#    'distance': 5118.690592147886},
#   {'id': 'oRdM7n-AfBPBGAlH4Q0Sag',
#    'alias': 'my-pie-pizzeria-romana-new-york-2',
#    'name': 'My Pie Pizzeria Romana',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vo36uaolTTa5aREAcddJnw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/my-pie-pizzeria-romana-new-york-2?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 754,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7608512, 'longitude': -73.9694809},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '690 Lexington Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['690 Lexington Ave', 'New York, NY 10022']},
#    'phone': '+12123171850',
#    'display_phone': '(212) 317-1850',
#    'distance': 6505.9564779774955},
#   {'id': 'oJ_XSPZFpvIt6rvheSQl7A',
#    'alias': 'bleecker-street-pizza-new-york',
#    'name': 'Bleecker Street Pizza',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Kyi2tP43S_a6s-zXD38NUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bleecker-street-pizza-new-york?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 2359,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7320627016512,
#     'longitude': -74.0036552270137},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '69 7th Ave S',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['69 7th Ave S', 'New York, NY 10014']},
#    'phone': '+12129244466',
#    'display_phone': '(212) 924-4466',
#    'distance': 3072.9540450669765},
#   {'id': 'S4uozcDEieoaXxIJ6TsUoQ',
#    'alias': 'dellaroccos-brooklyn-3',
#    'name': "Dellarocco's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RGsip2vQXryVUbOrXfYBkQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dellaroccos-brooklyn-3?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 275,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6950309, 'longitude': -73.9961252},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '214 Hicks St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['214 Hicks St', 'Brooklyn, NY 11201']},
#    'phone': '+17188581010',
#    'display_phone': '(718) 858-1010',
#    'distance': 1170.2700329972115},
#   {'id': 'i_rg-OLXQbpRUN7O3MeCeA',
#    'alias': 'piz-zetta-brooklyn-2',
#    'name': 'Piz-zetta',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9L4viDwAGx3obgYLnXMA6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/piz-zetta-brooklyn-2?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 290,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6912834070746,
#     'longitude': -73.9906029201042},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '90 Livingston St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['90 Livingston St', 'Brooklyn, NY 11201']},
#    'phone': '+17184227878',
#    'display_phone': '(718) 422-7878',
#    'distance': 1605.1176697811002},
#   {'id': 'hGksyTiHBBdrhbiVjXzWVw',
#    'alias': 'scarrs-pizza-new-york',
#    'name': "Scarr's Pizza",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/k3iXzXNevY7-CuIbE0-FaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/scarrs-pizza-new-york?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 410,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71534, 'longitude': -73.9914},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '22 Orchard St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['22 Orchard St', 'New York, NY 10002']},
#    'phone': '+12123343481',
#    'display_phone': '(212) 334-3481',
#    'distance': 1125.7843300426755},
#   {'id': 'LF1QAuvpfX7KGQlg2zMg6Q',
#    'alias': 'johns-of-bleecker-street-new-york-2',
#    'name': "John's of Bleecker Street",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/azvVfskp-0QuI4G51R8_VA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/johns-of-bleecker-street-new-york-2?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 2051,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73158, 'longitude': -74.00332},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '278 Bleecker St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['278 Bleecker St', 'New York, NY 10014']},
#    'phone': '+12122431680',
#    'display_phone': '(212) 243-1680',
#    'distance': 3010.899021476809},
#   {'id': 'uc5qQMzs96rzjK27epDCug',
#    'alias': 'joes-pizza-new-york-4',
#    'name': "Joe's Pizza",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1TvTRG9HFmEGaTSBMcUBhA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joes-pizza-new-york-4?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 2556,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73060076, 'longitude': -74.00215997},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '7 Carmine St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7 Carmine St', 'New York, NY 10014']},
#    'phone': '+12123661182',
#    'display_phone': '(212) 366-1182',
#    'distance': 2874.702513677348},
#   {'id': '0UdC0VYX6aAvLiOcpR4MVQ',
#    'alias': 'joes-pizza-new-york-7',
#    'name': "Joe's Pizza",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9E2Um0ddicKyoWS-RGIXyg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joes-pizza-new-york-7?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 896,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73331, 'longitude': -73.98763},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '150 E 14th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['150 E 14th St', 'New York, NY 10003']},
#    'phone': '+12123889474',
#    'display_phone': '(212) 388-9474',
#    'distance': 3133.9130768847594},
#   {'id': 'xrgzB0pvsxeGEIboE6I2gg',
#    'alias': 'patsys-pizzeria-brooklyn-2',
#    'name': "Patsy's Pizzeria",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1n5xL5ojLR-_zseirQKaMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patsys-pizzeria-brooklyn-2?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 537,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6818695, 'longitude': -73.976181},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '450 Dean St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['450 Dean St', 'Brooklyn, NY 11217']},
#    'phone': '+17186222268',
#    'display_phone': '(718) 622-2268',
#    'distance': 3034.9893998767334},
#   {'id': 'KEEXuHCYhsQJ-zpJhu98bA',
#    'alias': 'joes-pizza-new-york-148',
#    'name': "Joe's Pizza",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5P5i2QZhxCen55PNdU_TTg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joes-pizza-new-york-148?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 1111,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7545841255557,
#     'longitude': -73.9870039190341},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '1435 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1435 Broadway', 'New York, NY 10018']},
#    'phone': '+16465594878',
#    'display_phone': '(646) 559-4878',
#    'distance': 5498.444221355099},
#   {'id': 'MwcRbM6lS6_8N67LmyBELA',
#    'alias': '99-cent-fresh-pizza-new-york-5',
#    'name': '99 Cent Fresh Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yy7ZIhBQiVIsoBINay-MIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/99-cent-fresh-pizza-new-york-5?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 533,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76458, 'longitude': -73.98247},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '1723 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1723 Broadway', 'New York, NY 10019']},
#    'phone': '+12122452155',
#    'display_phone': '(212) 245-2155',
#    'distance': 6652.683137648691},
#   {'id': 'vyoA8dxwScuMV_AsTcjQcg',
#    'alias': 'l-and-b-spumoni-gardens-brooklyn',
#    'name': 'L & B Spumoni Gardens',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BrTci9PjIwi7V1vkbgkdqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-and-b-spumoni-gardens-brooklyn?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 3841,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.594715, 'longitude': -73.981316},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '2725 86th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11223',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2725 86th St', 'Brooklyn, NY 11223']},
#    'phone': '+17184491230',
#    'display_phone': '(718) 449-1230',
#    'distance': 12361.163422806636},
#   {'id': '2xQmBB6w-W6lxiex80fA9A',
#    'alias': 'luigis-pizzeria-brooklyn-4',
#    'name': "Luigi's Pizzeria",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/B3eNfBS1DTkTZ6fasVL01A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/luigis-pizzeria-brooklyn-4?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 242,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6897, 'longitude': -73.965369},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '326 Dekalb Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['326 Dekalb Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17187832430',
#    'display_phone': '(718) 783-2430',
#    'distance': 3001.8318150390764},
#   {'id': '4h4Tuuc56YPO6lWfZ1bdSQ',
#    'alias': 'joes-pizza-new-york-152',
#    'name': "Joe's Pizza",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iiFPnKfxI2_UjJHbCd2iCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joes-pizza-new-york-152?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 205,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7101297729083,
#     'longitude': -74.0077206864953},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '124 Fulton St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['124 Fulton St', 'New York, NY 10038']},
#    'phone': '+12122670860',
#    'display_phone': '(212) 267-0860',
#    'distance': 1245.9428626945232},
#   {'id': 'ynQ8NJB7SEAIkuUxopHPvA',
#    'alias': 'ignazios-brooklyn',
#    'name': "Ignazio's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8X6uFKW7BksKs7H8GYsQxA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ignazios-brooklyn?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 525,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.703137, 'longitude': -73.993608},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '4 Water St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4 Water St', 'Brooklyn, NY 11201']},
#    'phone': '+17185222100',
#    'display_phone': '(718) 522-2100',
#    'distance': 263.0425018849065},
#   {'id': 'm3PS0tIaa0ChcP8Y5S-DrQ',
#    'alias': 'mamas-too-new-york',
#    'name': "MAMA'S TOO!",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NTpvPQSoxumdAuc6szUSyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mamas-too-new-york?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 379,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.80084, 'longitude': -73.96766},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2750 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2750 Broadway', 'New York, NY 10025']},
#    'phone': '+12125107256',
#    'display_phone': '(212) 510-7256',
#    'distance': 10840.163726815497},
#   {'id': '-CCfu19Uuy_kD2t4ZwsQfA',
#    'alias': 'village-square-pizza-new-york-3',
#    'name': 'Village Square Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rc1se5XkYcc6ABo8g7u4Zw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/village-square-pizza-new-york-3?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 146,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72748, 'longitude': -73.98268},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '147 Ave A',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['147 Ave A', 'New York, NY 10009']},
#    'phone': '+19176757709',
#    'display_phone': '(917) 675-7709',
#    'distance': 2640.263835248777},
#   {'id': 'DJSLGbSqCJ1W8ma3LFlMuw',
#    'alias': 'patzeria-perfect-pizza-new-york',
#    'name': 'Patzeria Perfect Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/w62on7rHWF6ZNTVy6M6RuQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patzeria-perfect-pizza-new-york?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 1608,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7594583, 'longitude': -73.9868048},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '231 W 46th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['231 W 46th St', 'New York, NY 10036']},
#    'phone': '+12125757646',
#    'display_phone': '(212) 575-7646',
#    'distance': 6040.144918807972},
#   {'id': 'QfCbV1_VIjfCkowro_WGNA',
#    'alias': 'luigis-pizza-brooklyn',
#    'name': "Luigi's Pizza",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WsGK3FQqwN79wtbczYR3ZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/luigis-pizza-brooklyn?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 334,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.66163, 'longitude': -73.99334},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '686 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['686 5th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17184993857',
#    'display_phone': '(718) 499-3857',
#    'distance': 4871.026714671667},
#   {'id': 'zmIrZgWhRdyRMrnEs9D3KA',
#    'alias': 'la-margarita-pizzeria-new-york',
#    'name': 'La Margarita Pizzeria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/F8l2OEzG76eciSf46rOQgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-margarita-pizzeria-new-york?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 291,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7215392420787,
#     'longitude': -73.9876275438289},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '168 Ludlow St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['168 Ludlow St', 'New York, NY 10002']},
#    'phone': '+19172614983',
#    'display_phone': '(917) 261-4983',
#    'distance': 1875.7222956933838},
#   {'id': 'GRXvvB1OKMuW4XDWEaVAlg',
#    'alias': 'joes-pizza-brooklyn-8',
#    'name': "Joe's Pizza",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7RQebflR3JvTcMWRbVC86g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joes-pizza-brooklyn-8?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 330,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71691, 'longitude': -73.958987},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '216 Bedford Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['216 Bedford Ave', 'Brooklyn, NY 11249']},
#    'phone': '+17183882216',
#    'display_phone': '(718) 388-2216',
#    'distance': 3239.2966565668607},
#   {'id': 'oOr6Ta5gZyDl6PyZ1cq7pg',
#    'alias': 'east-village-pizza-new-york',
#    'name': 'East Village Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JovsXYGUD7K98X-dWrPzYw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/east-village-pizza-new-york?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 291,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.728199, 'longitude': -73.985182},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '145 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['145 1st Ave', 'New York, NY 10003']},
#    'phone': '+12125294545',
#    'display_phone': '(212) 529-4545',
#    'distance': 2643.8575043591286},
#   {'id': 'c3D2ckzacnPtdGIM8tb-_w',
#    'alias': 'b-side-pizza-and-wine-bar-new-york',
#    'name': 'B Side Pizza & Wine Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0oC3VssQ0t1gSEEf9HWlmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/b-side-pizza-and-wine-bar-new-york?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 1142,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76394, 'longitude': -73.9883399},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '370 W 51st St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['370 W 51st St', 'New York, NY 10019']},
#    'phone': '+16466797225',
#    'display_phone': '(646) 679-7225',
#    'distance': 6519.850090048231},
#   {'id': 'xRiLLXjeM2wOvVTYJH2__A',
#    'alias': 'barboncino-pizza-and-bar-brooklyn-2',
#    'name': 'Barboncino Pizza & Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/48doX4sxCRLxOl8a6AD35Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barboncino-pizza-and-bar-brooklyn-2?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 972,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.67206, 'longitude': -73.95717},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '781 Franklin Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['781 Franklin Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17182183300',
#    'display_phone': '(718) 218-3300',
#    'distance': 4850.790371389969},
#   {'id': 'kVrTff8uDMSBAaceBwQ7dg',
#    'alias': 'saluggis-new-york',
#    'name': "Saluggi's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/P_NI4AhmWBAi4c33PViGMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saluggis-new-york?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 559,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.720104, 'longitude': -74.003578},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '325 Church St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['325 Church St', 'New York, NY 10013']},
#    'phone': '+12122267900',
#    'display_phone': '(212) 226-7900',
#    'distance': 1808.5885826304711},
#   {'id': 'uEKiv6WEPg9dWj10HCur5A',
#    'alias': 'table-87-brooklyn-heights-brooklyn-2',
#    'name': 'Table 87 - Brooklyn Heights',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/CX-0-ASjoOQ1jfazjjaD_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/table-87-brooklyn-heights-brooklyn-2?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 276,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.691219329834,
#     'longitude': -73.9973449707031},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '87 Atlantic Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['87 Atlantic Ave', 'Brooklyn, NY 11201']},
#    'phone': '+17187979300',
#    'display_phone': '(718) 797-9300',
#    'distance': 1602.5908124268826},
#   {'id': '-9NO2IDCJMyNGZMAQ1-VQw',
#    'alias': 'ny-pizza-suprema-new-york',
#    'name': 'NY Pizza Suprema',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/EqbDXneMuQP6pw6GemVdQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ny-pizza-suprema-new-york?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 2016,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7502059936523,
#     'longitude': -73.9953231811523},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '413 8th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['413 8th Ave', 'New York, NY 10001']},
#    'phone': '+12125948939',
#    'display_phone': '(212) 594-8939',
#    'distance': 4977.847939164096},
#   {'id': 'CAGAWbPE8uPr2VVvEnv0ZA',
#    'alias': 'ribalta-pizza-new-york',
#    'name': 'Ribalta Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/O6RftJPph1inJ4dbf6o3rw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ribalta-pizza-new-york?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 570,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7334346, 'longitude': -73.9916923},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '48 E 12th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['48 E 12th St', 'New York, NY 10003']},
#    'phone': '+12127777781',
#    'display_phone': '(212) 777-7781',
#    'distance': 3120.0223255782057},
#   {'id': 'VP3-iMnKK_TaHDuy6mxTzA',
#    'alias': 'scotts-pizza-tours-new-york',
#    'name': "Scott's Pizza Tours",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/63kgRKCa4_WTjfBEkcZeOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/scotts-pizza-tours-new-york?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 314,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'foodtours', 'title': 'Food Tours'},
#     {'alias': 'walkingtours', 'title': 'Walking Tours'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.750244140625,
#     'longitude': -73.9970245361328},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['New York, NY 10001']},
#    'phone': '+12129139903',
#    'display_phone': '(212) 913-9903',
#    'distance': 5379.773739687928},
#   {'id': 'YuzOnNDfRKixNJiaVy5Baw',
#    'alias': 'robertas-pizza-new-york-2',
#    'name': "Roberta's Pizza",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DfRh3ueUr2FONIMGoitPMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/robertas-pizza-new-york-2?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 216,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7545170712701,
#     'longitude': -73.9765970005763},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '230 Park Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10169',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['230 Park Ave', 'New York, NY 10169']},
#    'phone': '+16467470820',
#    'display_phone': '(646) 747-0820',
#    'distance': 5656.648409458703},
#   {'id': 'Kh0-HmlgmVUkRxR55_Vn1g',
#    'alias': 'patsys-pizzeria-new-york-7',
#    'name': "Patsy's Pizzeria",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gXl9HrfT338PuJpwPjlUkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patsys-pizzeria-new-york-7?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 840,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.797157, 'longitude': -73.93488},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2287 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10035',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2287 1st Ave', 'New York, NY 10035']},
#    'phone': '+12125349783',
#    'display_phone': '(212) 534-9783',
#    'distance': 11359.776930320333},
#   {'id': '58YvTYsyxNyGixTAZiMHcg',
#    'alias': 'williamsburg-pizza-new-york-3',
#    'name': 'Williamsburg Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uMXAMUisv9ehDKRBKDU9DQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/williamsburg-pizza-new-york-3?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 228,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71822, 'longitude': -73.99123},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '277 Broome St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['277 Broome St', 'New York, NY 10002']},
#    'phone': '+12122264455',
#    'display_phone': '(212) 226-4455',
#    'distance': 1447.5435085978659},
#   {'id': 'atbANdSznV29GI066I2Ijw',
#    'alias': 'champion-pizza-new-york-6',
#    'name': 'Champion Pizza',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/zDLR1A5Nra5wP6fHdnoIgw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/champion-pizza-new-york-6?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 314,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7215270996094,
#     'longitude': -73.9970855712891},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '17 Cleveland Pl',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['17 Cleveland Pl', 'New York, NY 10012']},
#    'phone': '+12122263777',
#    'display_phone': '(212) 226-3777',
#    'distance': 1801.4764439408825},
#   {'id': '15k7iqFbhf4h8L01yggLqg',
#    'alias': 'song-e-napule-new-york',
#    'name': 'Song E Napule',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/y9G-nheTrxSrx4Cqg0HzHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/song-e-napule-new-york?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 489,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72813, 'longitude': -74.00188},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '146 W Houston St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['146 W Houston St', 'New York, NY 10012']},
#    'phone': '+12125331242',
#    'display_phone': '(212) 533-1242',
#    'distance': 2607.168270554507},
#   {'id': 'hFmz7HH2og9hn7xNNv20yw',
#    'alias': 'il-porto-ristorante-brooklyn',
#    'name': 'Il Porto Ristorante',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ka4_bkUB_I5JAZyRjAnbLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-porto-ristorante-brooklyn?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 331,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6974427, 'longitude': -73.9675197},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '37 Washington Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['37 Washington Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17186240954',
#    'display_phone': '(718) 624-0954',
#    'distance': 2433.138320005117},
#   {'id': 'ZTsN8TdMXl8SW_AKd_ablw',
#    'alias': 'forno-rosso-brooklyn',
#    'name': 'Forno Rosso',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9aKNymymd9out1HSpkLuiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/forno-rosso-brooklyn?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 680,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.694467, 'longitude': -73.98293},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '327 Gold St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['327 Gold St', 'Brooklyn, NY 11201']},
#    'phone': '+17184513800',
#    'display_phone': '(718) 451-3800',
#    'distance': 1546.804489135146},
#   {'id': 'orvnuNWLuoE3-iEx4Aj8eA',
#    'alias': 'bakers-pizza-new-york',
#    'name': "Baker's Pizza",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TnZDjIPAm9nwfzV2ldWGiw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bakers-pizza-new-york?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 221,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7294399, 'longitude': -73.98125},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '201 Avenue A',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['201 Avenue A', 'New York, NY 10009']},
#    'phone': '+12127777477',
#    'display_phone': '(212) 777-7477',
#    'distance': 2886.890664336274},
#   {'id': 'AoezuAP-QOH6JZZOmyzJLg',
#    'alias': 'marinara-pizza-new-york-11',
#    'name': 'Marinara Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3pb0XoJkF5Zx6ZPwjfpdfw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marinara-pizza-new-york-11?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 261,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7826, 'longitude': -73.95351},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '1376 Lexington Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1376 Lexington Ave', 'New York, NY 10128']},
#    'phone': '+16465595100',
#    'display_phone': '(646) 559-5100',
#    'distance': 9241.472431640696},
#   {'id': 'cqDVdoLA_36vpz2qxWdBqA',
#    'alias': 'uncle-tonys-pizza-new-york',
#    'name': "Uncle Tony's Pizza",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yzL2HXHaitE_noHhSUWm7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/uncle-tonys-pizza-new-york?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 117,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.82139, 'longitude': -73.95066},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1596 Amsterdam Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10031',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1596 Amsterdam Ave', 'New York, NY 10031']},
#    'phone': '+12126907500',
#    'display_phone': '(212) 690-7500',
#    'distance': 13402.224402800999},
#   {'id': 'FKzpfWUpyupl4q74Jt8fTA',
#    'alias': 'don-antonio-new-york-5',
#    'name': 'Don Antonio',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Kwv16TeExWDWWLLbCNq7Cw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/don-antonio-new-york-5?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 1429,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.762711, 'longitude': -73.986708},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '309 W 50th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['309 W 50th St', 'New York, NY 10019']},
#    'phone': '+16467191043',
#    'display_phone': '(646) 719-1043',
#    'distance': 6399.689323736132},
#   {'id': 'lxPVSGnZ7YTiO5OGrqBS8Q',
#    'alias': 'vinnies-pizzeria-brooklyn',
#    'name': "Vinnie's Pizzeria",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/T35Yd0xRbxwjaFJJ-CjiBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vinnies-pizzeria-brooklyn?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 675,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7189, 'longitude': -73.956843},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '148 Bedford Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['148 Bedford Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17187827078',
#    'display_phone': '(718) 782-7078',
#    'distance': 3489.0079917146263},
#   {'id': 'yH6t1JWcwkdWG4CS5KPvow',
#    'alias': 'adriennes-pizzabar-new-york',
#    'name': "Adrienne's Pizzabar",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MOG8wpqkeYQxDslq7ospLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/adriennes-pizzabar-new-york?adjust_creative=clCXICX9m9GSlzv5cn3yIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=clCXICX9m9GSlzv5cn3yIQ',
#    'review_count': 1658,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7043362, 'longitude': -74.0101733},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '54 Stone St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['54 Stone St', 'New York, NY 10004']},
#    'phone': '+12122483838',
#    'display_phone': '(212) 248-3838',
#    'distance': 1344.2671600758972}],
#  'total': 7500,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %% [markdown]
# The final important note is how some of the parameters have alternative formats. For example, `limit` is an integer and `open_now` is a boolean according to the documentation. Following these conventions is essential to receiving valid responses.
#
# # Summary
#
# Congratulations! Not only have you seen an API now, you've also practiced sifting through the documentation. The last piece in working with APIs is developing a more solid understanding of JSON files; the data format typically returned by modern APIs. Take some additional time and familiarize yourself with some further aspects of the documentation which you may wish to investigate in the upcoming lab!
